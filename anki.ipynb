# %%
anki_path = r'C:\Users\hui\AppData\Local\Programs\Anki\anki.exe'

nested_bullet_points_prompt = '''Summarize the following text in a nested bullet point format so the output can be pasted into Workflowy which requires the following format:

- Title
    - Subtitle
        - Sub-subtitle
            - Key point
            - Key point

Each level should be indented using 4 spaces for clarity.
Begin all bullet points with a dash followed by a single space.
Avoid using hashtags or any special characters such as asterisks or numbering.
Do not add any additional commentary or explanations. Only present the summarized bullet points.'''

anki_cloze_cards_prompt = '''Generate Anki-style cloze deletion flashcards from every key point in the passage below.
- Do not miss any key points
- Use the format `{{c1::hidden text}}`
- Turn key facts, terms, or concepts into cloze deletions
- Each card should be on a new line
- Do not add any additional commentary or explanations.
- Only present the cloze deletion cards.
- Example Outputs (These are examples. Do NOT generate the following):
The {{c1::mitochondrion}} is known as the powerhouse of the cell.
It generates most of the cell's supply of {{c1::ATP}}.
ATP is used as a source of {{c1::chemical energy}}.'''

# %%
import os
import time
import psutil
import requests
import webbrowser
import subprocess
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
DEEPSEEK_KEY = os.getenv('DEEPSEEK_KEY')

client = OpenAI(
    api_key=DEEPSEEK_KEY,
    base_url="https://api.deepseek.com"
)

def get_llm_response(user_input, system_input=None):
    messages = [{ "role": "user", "content": user_input}]
    if system_input:
        messages = [
            {"role": "system", "content": system_input},
        ] + messages
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=messages,
        stream=False
    )

    return response.choices[0].message.content


def get_nested_bullet_points(user_input):
    print('Generating nested bullet points...')
    return get_llm_response(user_input, nested_bullet_points_prompt)


def get_anki_cloze_cards(user_input):
    print('Generating Anki cloze cards...')
    str_output = get_llm_response(user_input, anki_cloze_cards_prompt)
    str_output = str_output.replace('\n\n', '\n')
    cloze_cards = [card.strip() for card in str_output.split('\n')]
    return cloze_cards

def start_anki():
    print('Starting Anki...')
    subprocess.Popen(anki_path)
    time.sleep(5)


def create_deck(deck_name):
    print(f'Creating deck: {deck_name}')
    requests.post('http://localhost:8765', json={
        'action': 'createDeck',
        'version': 6,
        'params': {
            'deck': deck_name
        }
    })


def get_title_body_lists(path):

    with open(path, 'r', errors='ignore') as f:
        contents = f.read()

    title_body_lists = []
    contents = contents.split('~~~~~')
    zfill_len = len(str(len(contents)))
    should_enumerate = len(contents) > 1
    for i, content in enumerate(contents):
        title, *body = content.strip().split('\n')
        try:
            title = title.split('. ')[1]
        except:
            pass
        if should_enumerate:
            title = f'{str(i+1).zfill(zfill_len)} {title}'
        body = '\n'.join(body)
        title_body_lists.append((title, body))

    return title_body_lists


def add_cloze_cards(deck_name, cloze_cards):
    print('Adding cloze cards to deck:')
    for cloze_card in cloze_cards:
        note = {
            'deckName': deck_name,
            'modelName': 'Cloze',
            'fields': {
                'Text': cloze_card
            },
            'options': {
                'allowDuplicate': True
            },
            'tags': []
        }

        payload = {
            'action': 'addNote',
            'version': 6,
            'params': {
                'note': note
            }
        }

        try:
            response = requests.post('http://localhost:8765', json=payload).json()
            if 'error' in response and response['error']:
                print(f'Failed to add card: {cloze_card}\nError: {response["error"]}')
            else:
                print(f'Added card: {cloze_card}')
        except Exception as e:
            print(f'Exception occurred: {e}')


def sync_anki():
    print('Syncing Anki...')
    requests.post("http://localhost:8765", json={
        "action": "sync",
        "version": 6
    })


def stop_anki():
    for proc in psutil.process_iter(['name']):
        if proc.info['name'] and 'anki' in proc.info['name']:
            print(f'''Terminating {proc.info['name']}''')
            proc.terminate()


def open_ankiweb():
    print('Opening AnkiWeb...')
    webbrowser.open('https://ankiweb.net')


def create_cloze_cards_and_sync(suffix, path='anki.txt'):

    title_body_lists = get_title_body_lists(path)
    response = input('\n'.join([t for t, _ in title_body_lists]) + '\nWould you like to create these decks? (y/n) ')
    if response.strip().lower() != 'y':
        return

    start_anki()
    for title, passage in title_body_lists:
        if suffix and not suffix.endswith('::'):
            suffix += '::'
        deck_name = suffix + title
        create_deck(deck_name)
        cloze_cards = get_anki_cloze_cards(passage)
        add_cloze_cards(deck_name, cloze_cards)

    sync_anki()
    # stop_anki()
    # open_ankiweb()

# %%
create_cloze_cards_and_sync('AllTrue::Walkthroughs::4. Compliance')
# Out:
# Starting Anki...
# Creating deck: AllTrue::Walkthroughs::4. Compliance1 Part 1
# Generating Anki cloze cards...
# Adding cloze cards to deck:
# Failed to add card: Here are the Anki-style cloze deletion flashcards based on the key points in the passage:
# Error: cannot create note for unknown reason
# Added card: 1. The session will cover {{c1::pentest categories}} in a separate session.
# Added card: 2. Today's session is substantial due to the complexity of {{c1::TPRM}} and {{c1::compliance audits}}.
# Added card: 3. System slowness is observed in modules due to the large scale of {{c1::TPRM}} and {{c1::compliance audits}}.
# Added card: 4. An example of task creation in the TPRM module is {{c1::Copilot task creation in Asana}}.
# Added card: 5. The current solution for notification issues is to instruct customers to adjust {{c1::notification settings upon invitation}}.
# Added card: 6. Only {{c1::customers}} can control their notification settings, with no permanent solution yet.
# Added card: 7. The impact of notification issues is temporary spam during workflow setup for about {{c1::10-15 minutes}}.
# Added card: 8. The problem is worse in the {{c1::EU AI Act}}, where users might receive {{c1::30 emails}} instead of 5.
# Added card: 9. The goal is to populate two modules simultaneously: {{c1::TPRM}} and {{c1::compliance}}.
# Added card: 10. Both TPRM and compliance features are heavily {{c1::checklist-oriented}}.
# Added card: 11. The process begins with a {{c1::risk assessment}} and filters requirements based on {{c1::AI system details}}.
# Added card: 12. Asana is used for {{c1::task management}}, mirroring the compliance/TPRM workflow.
# Added card: 13. The compliance module currently supports three frameworks: {{c1::ISO 42001}}, {{c1::EU AI Act}}, and {{c1::NIST AI RMF}}.
# Added card: 14. Expansion of supported frameworks is slow due to limited {{c1::legal staff}}.
# Added card: 15. The {{c1::EU AI Act}} is particularly time-consuming to implement.
# Added card: 16. The {{c1::Compliance Compass}} maps frameworks/audits needed for a project.
# Added card: 17. Users fill out a {{c1::14-question questionnaire}} to determine required frameworks.
# Added card: 18. The {{c1::EU AI Act}} is mandatory for EU-based generative AI systems.
# Added card: 19. Users can adjust audit frequency, such as setting it to {{c1::semiannually}}.
# Added card: 20. Backend policies check for {{c1::completion of audits}} and {{c1::manual compliance declarations}}.
# Added card: 21. Detailed audits are only supported for {{c1::three frameworks}}.
# Added card: 22. Mappings exist for additional frameworks like the {{c1::Singaporean Model AI Governance Framework}}.
# Added card: 23. Tags assigned to a project are based on {{c1::user answers}}.
# Added card: 24. The dashboard shows {{c1::three audit gaps}} for the three required frameworks.
# Added card: 25. The heat map shows compliance percentages, with non-supported frameworks {{c1::grayed out}}.
# Added card: 26. Users can manually mark gaps as completed, updating the compliance percentage to {{c1::100%}}.
# Added card: 27. External audits are {{c1::customer-managed}} and tracked within the platform.
# Added card: 28. Platform-supported audits are initiated {{c1::directly through the system}}.
# Creating deck: AllTrue::Walkthroughs::4. Compliance2 Part 2
# Generating Anki cloze cards...
# Adding cloze cards to deck:
# Failed to add card: Here are the Anki-style cloze deletion flashcards generated from the key points in the passage:
# Error: cannot create note for unknown reason
# Added card: 1. There are two methods to initiate audits: {{c1::Via Dashboard Gap}} and {{c1::Via Audit Page}}.
# Added card: 2. In the Dashboard Gap method, you click {{c1::"Initiate Audit"}}, then select {{c1::project}}, assign {{c1::owner}}, and set {{c1::due date}}.
# Added card: 3. In the Audit Page method, you select {{c1::framework}} (e.g., EU AI Act), then assign {{c1::user}} and {{c1::due date}}.
# Added card: 4. Required policies for ISO 42001 compliance are stored in the {{c1::Knowledge Hub}}.
# Added card: 5. Policies can be added either by {{c1::uploading manually}} or by using {{c1::templates}}.
# Added card: 6. When uploading manually, policies appear in the {{c1::"Approved"}} tab.
# Added card: 7. The Policy Builder workflow starts with collecting {{c1::background documentation}} followed by {{c1::yes/no questions}}.
# Added card: 8. Compliance tracking shows {{c1::binary status}} (0% or 100%) with no partial completion.
# Added card: 9. The system operates on a {{c1::webhook-based}} mechanism where user actions trigger backend processes.
# Added card: 10. A {{c1::transaction processor}} runs every {{c1::2 minutes}} to handle queued tasks.
# Added card: 11. For EU AI Act compliance, the Risk Assessment Section contains approximately {{c1::150 questions}}.
# Added card: 12. The system uses {{c1::Retrieval Augmented Generation (RAG)}} to answer questions from document chunks stored as vectors.
# Added card: 13. Policies can range from {{c1::3 pages}} to {{c1::100+ pages}} in length.
# Added card: 14. The audit report structure includes {{c1::cover page}}, {{c1::audit outcome}}, and {{c1::detailed findings}}.
# Added card: 15. For bias detection, the platform will include both {{c1::dataset bias}} and {{c1::model bias}} detection.
# Added card: 16. When uploading documents, the system breaks them into chunks and converts them into {{c1::vector embeddings}} stored in a {{c1::vector store}}.
# Added card: 17. The system automatically marks a category as complete when {{c1::all questions}} in it are answered.
# Added card: 18. Cloudflare integration for network logs requires generating an {{c1::API key}} in the admin console.
# Added card: 19. The platform currently has {{c1::23 categories}} in total for audits.
# Added card: 20. Approved documents are moved from {{c1::"Under review"}} to {{c1::"Approved"}} tab in the Knowledge Hub.
# Creating deck: AllTrue::Walkthroughs::4. Compliance3 Part 3
# Generating Anki cloze cards...
# Adding cloze cards to deck:
# Failed to add card: Here are the Anki-style cloze deletion flashcards generated from the key points in the passage:
# Error: cannot create note for unknown reason
# Added card: 1. The admin creates an API key called {{c1::Cloudflare Log Push API Key - DataDog Listener}} for Cloudflare setup.
# Added card: 2. Cloudflare logs help identify unauthorized usage of {{c1::LLM endpoints}}.
# Added card: 3. AI services like {{c1::ChatGPT}} and {{c1::Copilot}} are monitored via Cloudflare logs.
# Added card: 4. Copilot data can be accessed via {{c1::Azure Discovery}} if configured.
# Added card: 5. Discovered AI services auto-populate in the {{c1::AI Technologies Inventory}}.
# Added card: 6. The {{c1::Usage Dashboard}} creates issues if AI service usage is unsanctioned.
# Added card: 7. Currently supported integrations include {{c1::Cloudflare}} and {{c1::NetScope}}.
# Added card: 8. Future integration with {{c1::Zscaler}} is not possible due to lack of developer access.
# Added card: 9. Cloudflare logs are initially stored in the {{c1::Playground Amazon account}} before moving to the demo account.
# Added card: 10. The system marks AI services as {{c1::sanctioned}} or {{c1::unsanctioned}} in the inventory.
# Added card: 11. Newly discovered services are initially marked as {{c1::unreviewed}} by default.
# Added card: 12. Unprotected AI services should show issues for missing {{c1::platform protection}}.
# Added card: 13. Firewall logging is {{c1::on by default}} in Cloudflare.
# Added card: 14. Guardrail log action shows {{c1::input/output}} plus {{c1::triggered rule information}}.
# Added card: 15. The policy generation process uses {{c1::user responses}} to customize a template.
# Added card: 16. Uploaded documents in the Knowledge Hub are classified as {{c1::approved}}.
# Added card: 17. ISO audit requirements are {{c1::auto-generated}} for compliance.
# Added card: 18. The system pulls content from {{c1::uploaded policies}} to populate requirement answers.
# Added card: 19. Evidence screenshots show {{c1::source document pages}} for auditor traceability.
# Added card: 20. Human oversight is required to {{c1::manually mark tasks}} as complete for EU AI Act compliance.
# Added card: 21. Auto-population of requirements typically takes about {{c1::5 minutes}} for 11 questions.
# Added card: 22. Files uploaded to {{c1::Evidence Collection}} are mapped to answer policy questions.
# Added card: 23. The system may get stuck if actions are performed {{c1::too quickly}}.
# Added card: 24. Webhook re-triggers usually unstuck the system after {{c1::30 minutes}}.
# Creating deck: AllTrue::Walkthroughs::4. Compliance4 Part 4
# Generating Anki cloze cards...
# Adding cloze cards to deck:
# Failed to add card: Here are the cloze deletion flashcards for the key points:
# Error: cannot create note for unknown reason
# Added card: 1. Testing recommendation: {{c1::Rapidly click items}} to observe system behavior and learn how to unstick it.
# Added card: 2. Demo best practice: {{c1::Proceed deliberately}} to avoid webhook conflicts (vs. rapid clicking).
# Added card: 3. Safe practice: {{c1::Wait for category to turn green}} before proceeding to next action.
# Added card: 4. AI Policy supports {{c1::ISO 42001}} compliance.
# Added card: 5. Questions answered in AI Policy feed back into the {{c1::main ISO 42001 workflow}}.
# Added card: 6. Uploaded policy (if compliant) will automatically {{c1::satisfy the 11 questions}} once the system unsticks.
# Added card: 7. Workflow step 1: {{c1::Upload policy to Evidence Collection}}.
# Added card: 8. Workflow step 2: {{c1::System answers applicable questions}}.
# Added card: 9. Workflow step 3: {{c1::Complete remaining questions manually}}.
# Added card: 10. Workflow step 4: {{c1::Results propagate to the main audit workflow}}.
# Added card: 11. Policy Template Project marked as {{c1::Completed}} with notification to access file in {{c1::Knowledge Hub}}.
# Added card: 12. AI Policy Draft moves from {{c1::Draft}} → {{c1::Under Review}} in Knowledge Hub.
# Added card: 13. Generated document title: {{c1::"My Acme AI Policy"}}.
# Added card: 14. Post-generation workflow: User updates Word doc → {{c1::saves as PDF}} → re-uploads.
# Added card: 15. Click {{c1::Approve}} → Policy moves from Under Review → {{c1::Approved}}.
# Added card: 16. Approved policy is automatically {{c1::pulled into audits}}.
# Added card: 17. Standard workflow starts with {{c1::AI Policy Template}}.
# Added card: 18. Video Evidence Collection Meeting generates {{c1::Zoom link}} automatically.
# Added card: 19. User must {{c1::type the requirement question}} in the chat before answering.
# Added card: 20. System {{c1::screenshots user actions}} as evidence.
# Added card: 21. Chat transcript timestamps {{c1::map evidence to specific requirements}}.
# Added card: 22. Meeting summary is processed for {{c1::evidence}}.
# Added card: 23. Automated evidence response is visible in {{c1::the system}}.
# Added card: 24. All evidence is pulled into {{c1::the audit report appendix}}.
# Added card: 25. Steps to start evidence collection: 1. {{c1::Initiate meeting}} 2. {{c1::Type "start meeting"}} 3. {{c1::Click link}} 4. {{c1::Copy question name}} 5. {{c1::Leave meeting}}.
# Added card: 26. System pulls {{c1::recording from Zoom}} and analyzes {{c1::questions mentioned in chat}}.
# Added card: 27. Customers can submit {{c1::manual responses}} with immediate feedback.
# Added card: 28. Uploading AI policy document: AI reads through {{c1::PDF}} to answer questions.
# Added card: 29. Audit report includes: {{c1::Cover letter}}, {{c1::Overview}}, {{c1::Responses}}, {{c1::Risk assessment}}, {{c1::Outcome}}.
# Added card: 30. System may get stuck when processing {{c1::large files}}.
# Added card: 31. System highlights {{c1::outstanding requirements}} for tracking progress.
# Added card: 32. Current limitation: No {{c1::repeat notifications}} for updates.
# Added card: 33. If wrong comment submitted: System responds with {{c1::"Follow-up required: suggested correction"}}.
# Added card: 34. Issues are generated based on {{c1::severity and obviousness}} of non-compliance.
# Added card: 35. ISO compliance typically occurs {{c1::once a year}}.
# Added card: 36. Supported frameworks include: {{c1::EU AI Act}}, {{c1::ISO 42001}}, {{c1::NIST AI MF}}.
# Added card: 37. Platform focuses on {{c1::AI-related compliance}} (not HIPAA or GDPR unless explicitly added).
# Added card: 38. Automated documentation example: Mcast replaced manual spreadsheet with {{c1::automated BOM}}.
# Added card: 39. Compliance process typically quarterbacked by {{c1::internal auditors/compliance specialists}}.
# Added card: 40. Tasks can be delegated through {{c1::Asana}}.
# Added card: 41. System accommodates {{c1::guest access}} without full user accounts.
# Added card: 42. Asana offers {{c1::bulk actions}} for assigning and completing tasks.
# Added card: 43. Users must answer {{c1::environment-specific questions}} themselves or delegate internally.
# Added card: 44. TPRM module will be addressed in {{c1::follow-up session}} the next day.
# Syncing Anki...
